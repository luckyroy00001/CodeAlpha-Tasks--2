# %% [markdown]
# # Normalization

# %%
import pandas as pd 
import numpy as numpy
import seaborn as sns
import matplotlib.pylab as plt

# %%
dataFrame = pd.read_csv("C:\\Users\\lucky\\Downloads\\diabetes.csv")

# %%
dataFrame
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
dataFrame.head(20)
# Out:
#     Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0             6      148             72             35        0  33.6
# 1             1       85             66             29        0  26.6
# 2             8      183             64              0        0  23.3
# 3             1       89             66             23       94  28.1
# 4             0      137             40             35      168  43.1
# 5             5      116             74              0        0  25.6
# 6             3       78             50             32       88  31.0
# 7            10      115              0              0        0  35.3
# 8             2      197             70             45      543  30.5
# 9             8      125             96              0        0   0.0
# 10            4      110             92              0        0  37.6
# 11           10      168             74              0        0  38.0
# ...

# %%
dataFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
dataFrame.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
dataFrame.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
sns.pairplot(data=dataFrame,height=5.5)
plt.grid()
plt.show()

# %%
dataFrame.head(5)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
X = dataFrame[['Pregnancies','Glucose','BloodPressure']]

# %%
y= dataFrame['Outcome']

# %% [markdown]
# # Training And Testing

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,train_size=0.8,test_size=0.2,random_state=78)

# %%
X_train
# Out:
#      Pregnancies  Glucose  BloodPressure
# 100            1      163             72
# 361            5      158             70
# 178            5      143             78
# 443            8      108             70
# 433            2      139             75
# ..           ...      ...            ...
# 310            6       80             66
# 105            1      126             56
# 40             3      180             64
# 470            1      144             82
# 709            2       93             64
#
# [614 rows x 3 columns]

# %%
X_test
# Out:
#      Pregnancies  Glucose  BloodPressure
# 533            6       91              0
# 62             5       44             62
# 421            2       94             68
# 751            1      121             78
# 577            2      118             80
# ..           ...      ...            ...
# 327           10      179             70
# 345            8      126             88
# 746            1      147             94
# 365            5       99             54
# 543            4       84             90
#
# [154 rows x 3 columns]

# %%
y_train
# Out:
# 100    1
# 361    0
# 178    0
# 443    1
# 433    0
#       ..
# 310    0
# 105    0
# 40     0
# 470    0
# 709    1
# Name: Outcome, Length: 614, dtype: int64

# %%
y_test
# Out:
# 533    0
# 62     0
# 421    0
# 751    0
# 577    1
#       ..
# 327    0
# 345    0
# 746    1
# 365    0
# 543    0
# Name: Outcome, Length: 154, dtype: int64

# %% [markdown]
# # Normalization

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
Norm_MMS = MinMaxScaler()

# %%
Norm_MMS_train = Norm_MMS.fit_transform(X_train)

# %%
Norm_MMS_tset = Norm_MMS.fit_transform(X_test)

# %%
Norm_MMS_train_dataFrame = pd.DataFrame(Norm_MMS_train,columns=['Pregnancies','Glucose','BloodPressure'])

# %%
Norm_MMS_train_dataFrame.head()
# Out:
#    Pregnancies   Glucose  BloodPressure
# 0     0.058824  0.819095       0.590164
# 1     0.294118  0.793970       0.573770
# 2     0.294118  0.718593       0.639344
# 3     0.470588  0.542714       0.573770
# 4     0.117647  0.698492       0.614754

# %%
Norm_MMS_tset_dataFrame = pd.DataFrame(Norm_MMS_tset,columns=['Pregnancies','Glucose','BloodPressure'])

# %%
Norm_MMS_tset_dataFrame.head()
# Out:
#    Pregnancies   Glucose  BloodPressure
# 0     0.428571  0.461929           0.00
# 1     0.357143  0.223350           0.62
# 2     0.142857  0.477157           0.68
# 3     0.071429  0.614213           0.78
# 4     0.142857  0.598985           0.80
